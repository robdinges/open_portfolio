# %%
# Voeg prijzen toe
currency_prices.add_price('USD', date(2024,1,1), 0.9250)
currency_prices.add_price('EUR', date(2024,1,1), 1.0)

# %%
# Voeg producten toe
bond = Bond(instrument_id=101, description="NL GOV 5% 2024", minimum_purchase_value=1000, smallest_trading_unit=1000, issue_currency='EUR', start_date=date(2024, 1, 1), maturity_date=date(2024, 12, 31), interest_rate=0.05, interest_payment_frequency=PaymentFrequency.YEAR)
stock = Stock(product_id=201, description="Apple Inc.", minimum_purchase_value=1, smallest_trading_unit=1, issue_currency='USD')
product_collection.add_product(bond)
product_collection.add_product(stock)

# %%
# Voeg cash accounts toe
portfolio.add_cash_account(account_id=1, account_type=AccountType.CASH, start_balance=5000, currency='EUR')
portfolio.add_cash_account(account_id=2, account_type=AccountType.CASH, start_balance=2000, currency='USD')

# %%
# Maak een client en portefeuille aan
client = Client(client_id=1, name="John Doe")
portfolio = client.add_portfolio(portfolio_id=1, default_currency='EUR', cost_in_transaction_currency=True)
portfolio_analytics = PortfolioAnalytics(portfolio)

# %%
# Initieer kernobjecten
time_travel = TimeTravel()
product_collection = ProductCollection()
transaction_manager = TransactionManager()
currency_prices = CurrencyPrices()

# %%
from open_portfolio import *
from datetime import date
import logging

# Logging minimaliseren
logging.basicConfig(level=logging.ERROR)

# %% [markdown]
# # Portfolio Simulatie (OpenPortfolio)
# Deze notebook demonstreert het opzetten van een eenvoudige portefeuille, het toevoegen van producten, cash accounts en het uitvoeren van transacties met de OpenPortfolio library.

# %%
from OpenPortfolioLib import *

# %%
from datetime import date
import logging

time_travel = TimeTravel()

# Initialize logging
logging.basicConfig(level=logging.ERROR)

# Initialize the necessary objects
product_collection = ProductCollection()
transaction_manager = TransactionManager()

# Create a client
client = Client(client_id=1, name="John Doe")

# Add a portfolio to the client
portfolio = client.add_portfolio(portfolio_id=1, default_currency='EUR', cost_in_transaction_currency=True)
portfolio_analytics = PortfolioAnalytics(portfolio)

# Add a cash account to the portfolio
#portfolio.add_cash_account(account_id=123, start_balance=10000)
portfolio.add_cash_account(account_id=1, account_type=AccountType.CASH, start_balance=5000, currency='USD')

currency_prices = CurrencyPrices()
currency_prices.add_price('USD', date(2022,1,1), 1.1)
currency_prices.add_price('EUR', date(2022,1,1), .9, 'USD')

# %%
portfolio.list_accounts()
# Out:
# Accounts in Portfolio 1:
# +--------------+------------+----------------+-----------+
# |   Account ID | Currency   | Account Type   | Balance   |
# +==============+============+================+===========+
# |            1 | EUR        | CASH           | 0         |
# +--------------+------------+----------------+-----------+
# |            1 | USD        | CASH           | 5000      |
# +--------------+------------+----------------+-----------+
# |            1 | EUR        | Securities     | N/A       |
# +--------------+------------+----------------+-----------+

# %%
# Product 1
product1 = Stock(product_id=1, description="ABC Corp", minimum_purchase_value=1, smallest_trading_unit=1, issue_currency='EUR')
product_collection.add_product(product1)

# Create and execute a buy transaction
transaction_manager.create_and_execute_transaction(
    transaction_date=date(2022, 1, 5),
    portfolio_id=1,
    template=TransactionTemplate.BUY,
    portfolio=portfolio,
    currency_prices=currency_prices,
    product_collection=product_collection,
    product_id=1,
    amount=2,
    price=3.5,
    #cost=10
)

# Create and execute a buy transaction
transaction_manager.create_and_execute_transaction(
    transaction_date=date(2022, 2, 20),
    portfolio_id=portfolio.portfolio_id,
    template=TransactionTemplate.SELL,
    portfolio=portfolio,
    currency_prices=currency_prices,
    product_collection=product_collection,
    product_id=1,
    amount=1,
    price=3.1,
    #cost=10
)

product_collection.list_products()
portfolio.list_holdings(time_travel, date(2022,12,31))
# Out:
# ERROR:root:Transaction validation (1) failed with messages: ['Insufficient balance for the total transaction amount in EUR. Account balance: 0, Required: 7.07']
# ERROR:root:Transaction validation (2) failed with messages: ['Insufficient holdings for product 1.']
# Product Collection:
# +-----------------+---------------+--------+--------------------------+-------------------------+------------------+--------------+-----------------+-----------------+---------------------+
# |   Instrument ID | Description   | Type   |   Minimum Purchase Value |   Smallest Trading Unit | Issue Currency   | Start Date   | Maturity Date   | Interest Rate   | Payment Frequency   |
# +=================+===============+========+==========================+=========================+==================+==============+=================+=================+=====================+
# ...

# %%
# Product 2
product2 = Bond(instrument_id=2, description="XYZ Bond", minimum_purchase_value=1000, smallest_trading_unit=1000, issue_currency='EUR', start_date=date(2021, 1, 1), maturity_date=date(2028, 1, 1), interest_rate=0.1, interest_payment_frequency=PaymentFrequency.YEAR)
product_collection.add_product(product2)
product2.add_price(date(2022,1,1), 100.0)
product2.add_price(date(2022,2,1), 100.0)
product2.add_price(date(2022,3,1), 100.0)
product2.add_price(date(2022,4,1), 100.0)


transaction_manager.create_and_execute_transaction(
    transaction_date=date(2029, 5, 30),
    portfolio_id=portfolio.portfolio_id,
    template=TransactionTemplate.BUY,
    portfolio=portfolio,
    currency_prices=currency_prices,
    product_collection=product_collection,
    product_id=2,
    amount=1000,
    price=1.0,
    #cost=10
)

# Create and execute a buy transaction
transaction_manager.create_and_execute_transaction(
    transaction_date=date(2022, 6, 10),
    portfolio_id=portfolio.portfolio_id,
    template=TransactionTemplate.SELL,
    portfolio=portfolio,
    currency_prices=currency_prices,
    product_collection=product_collection,
    product_id=2,
    amount=1000,
    price=1.01,
    #cost=10
)

product_collection.list_products()
portfolio.list_holdings(time_travel, date(2022,12,31))
# Out:
# ERROR:root:Transaction validation (3) failed with messages: ['Insufficient balance for the total transaction amount in EUR. Account balance: 0, Required: 1849.0710382513662', 'The transaction date for product 2 is outside the valid date range (2021-01-01 to 2028-01-01).']
# ERROR:root:Transaction validation (4) failed with messages: ['Insufficient holdings for product 2.']
# Product Collection:
# +-----------------+---------------+--------+--------------------------+-------------------------+------------------+--------------+-----------------+-----------------+---------------------+
# |   Instrument ID | Description   | Type   |   Minimum Purchase Value |   Smallest Trading Unit | Issue Currency   | Start Date   | Maturity Date   | Interest Rate   | Payment Frequency   |
# +=================+===============+========+==========================+=========================+==================+==============+=================+=================+=====================+
# ...

# %%
# Product 3
product3 = Bond(instrument_id=3, description="Demo Bond", minimum_purchase_value=1000, smallest_trading_unit=1000, issue_currency='EUR', start_date=date(2022, 1, 1), maturity_date=date(2028, 1, 1), interest_rate=0.10, interest_payment_frequency=PaymentFrequency.YEAR)
product_collection.add_product(product3)
product3.add_price(date(2022,1,1), 1)
product3.add_price(date(2022,6,30), 3)


transaction_manager.create_and_execute_transaction(
    transaction_date=date(2022, 1, 2),
    portfolio_id=portfolio.portfolio_id,
    template=TransactionTemplate.BUY,
    portfolio=portfolio,
    currency_prices=currency_prices,
    product_collection=product_collection,
    product_id=3,
    amount=1000,
    price=1.0321,
    cost=101
)

# Create and execute a buy transaction
transaction_manager.create_and_execute_transaction(
    transaction_date=date(2022, 3, 10),
    portfolio_id=portfolio.portfolio_id,
    template=TransactionTemplate.BUY,
    portfolio=portfolio,
    product_collection=product_collection,
    currency_prices=currency_prices,
    product_id=product3.instrument_id,
    amount=1000,
    price=1.0003,
    cost=100
)
product_collection.list_products()

# Function to print the balance of a given account

# List the holdings in the portfolio after the transactions
portfolio.list_holdings(time_travel, date(2022,1,31))
portfolio.list_holdings(time_travel, date(2022,4,30))
# Out:
# ERROR:root:Transaction validation (5) failed with messages: ['Insufficient balance for the total transaction amount in EUR. Account balance: 0, Required: 1133.3739726027397']
# ERROR:root:Transaction validation (6) failed with messages: ['Insufficient balance for the total transaction amount in EUR. Account balance: 0, Required: 1118.9301369863012']
# Product Collection:
# +-----------------+---------------+--------+--------------------------+-------------------------+------------------+--------------+-----------------+-----------------+---------------------+
# |   Instrument ID | Description   | Type   |   Minimum Purchase Value |   Smallest Trading Unit | Issue Currency   | Start Date   | Maturity Date   | Interest Rate   | Payment Frequency   |
# +=================+===============+========+==========================+=========================+==================+==============+=================+=================+=====================+
# ...

# %%
# Product 4
product4 = Stock(product_id=4, description="Demo Bond", minimum_purchase_value=1, smallest_trading_unit=1, issue_currency='USD')
product_collection.add_product(product4)
product4.add_price(date(2022,1,1), 1)
product4.add_price(date(2022,6,30), 3)


transaction_manager.create_and_execute_transaction(
    transaction_date=date(2022, 1, 2),
    portfolio_id=portfolio.portfolio_id,
    template=TransactionTemplate.BUY,
    portfolio=portfolio,
    product_collection=product_collection,
    currency_prices=currency_prices,
    product_id=4,
    amount=10,
    price=200,
    cost=101
)

# Create and execute a buy transaction
transaction_manager.create_and_execute_transaction(
    transaction_date=date(2022, 3, 10),
    portfolio_id=portfolio.portfolio_id,
    template=TransactionTemplate.BUY,
    portfolio=portfolio,
    product_collection=product_collection,
    currency_prices=currency_prices,
    product_id=product4.instrument_id,
    amount=10,
    price=100
    #cost=100
)
product_collection.list_products()

# Function to print the balance of a given account

# List the holdings in the portfolio after the transactions
portfolio.list_holdings(time_travel, date(2022,1,31))
portfolio.list_holdings(time_travel, date(2022,4,30))
# Out:
# Product Collection:
# +-----------------+---------------+--------+--------------------------+-------------------------+------------------+--------------+-----------------+-----------------+---------------------+
# |   Instrument ID | Description   | Type   |   Minimum Purchase Value |   Smallest Trading Unit | Issue Currency   | Start Date   | Maturity Date   | Interest Rate   | Payment Frequency   |
# +=================+===============+========+==========================+=========================+==================+==============+=================+=================+=====================+
# |               1 | ABC Corp      | STOCK  |                        1 |                       1 | EUR              | N/A          | N/A             | N/A             | N/A                 |
# +-----------------+---------------+--------+--------------------------+-------------------------+------------------+--------------+-----------------+-----------------+---------------------+
# ...

# %%
# Display the transaction table
#portfolio.transactions_table()
portfolio.list_accounts()
# Out:
# Accounts in Portfolio 1:
# +--------------+------------+----------------+-----------+
# |   Account ID | Currency   | Account Type   | Balance   |
# +==============+============+================+===========+
# |            1 | EUR        | CASH           | 0         |
# +--------------+------------+----------------+-----------+
# |            1 | USD        | CASH           | 1889.0    |
# +--------------+------------+----------------+-----------+
# |            1 | EUR        | Securities     | N/A       |
# +--------------+------------+----------------+-----------+

# %%
# Display the returns table
portfolio.returns_table(start_date=date(2022, 1, 1), end_date=date(2022, 12, 31))
# Out:
# +--------------+------------+-------------+---------------+-----------------+---------------------+----------------------------+--------------------------------+
# | Start Date   | End Date   |   End Value |   Start Value |   Return Amount | Return Percentage   |   Cumulative Return Amount | Cumulative Return Percentage   |
# +==============+============+=============+===============+=================+=====================+============================+================================+
# | 2022-01-01   | 2022-12-31 |       -1162 |          5000 |           -6162 | -123.24%            |                      -6162 | -123.24%                       |
# +--------------+------------+-------------+---------------+-----------------+---------------------+----------------------------+--------------------------------+

# %%
# Example Usage
product_id_to_track = 1  # Replace with the actual product ID you want to track
progress = portfolio_analytics.get_holdings_progress(product_id_to_track)

# Display the progress
import pandas as pd
progress_df = pd.DataFrame(progress)
print(progress_df)

# Example Usage
product_id_to_track = 2  # Replace with the actual product ID you want to track
progress = portfolio_analytics.get_holdings_progress(product_id_to_track)

# Display the progress
progress_df = pd.DataFrame(progress)
print(progress_df)

# Example Usage
product_id_to_track = 3  # Replace with the actual product ID you want to track
progress = portfolio_analytics.get_holdings_progress(product_id_to_track)

# Display the progress
progress_df = pd.DataFrame(progress)
print(progress_df)
# Out:
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []

# %%
from OpenPortfolioLib import *
from datetime import date
import logging

# Initialize logging
logging.basicConfig(level=logging.ERROR)

# Initialize the necessary objects
time_travel = TimeTravel()
product_collection = ProductCollection()
transaction_manager = TransactionManager()
currency_prices = CurrencyPrices()

# Create a client
client = Client(client_id=10, name="Rob van der Erve")

# Add a portfolio to the client
portfolio10 = client.add_portfolio(portfolio_id=10, default_currency='EUR', cost_in_transaction_currency=True)
portfolio10.cash_accounts[(portfolio10.portfolio_id, 'EUR', AccountType.CASH)].balance = 15_000
portfolio10.add_cash_account(account_id=10, account_type=AccountType.CASH, start_balance=5000, currency='USD')
portfolio10.add_cash_account(account_id=10, account_type=AccountType.CASH, start_balance=1000, currency='GBP')
portfolio_analytics = PortfolioAnalytics(portfolio10)

# Add a portfolio to the client
portfolio20 = client.add_portfolio(portfolio_id=20, default_currency='EUR', cost_in_transaction_currency=True)
portfolio20.cash_accounts[(portfolio20.portfolio_id, 'EUR', AccountType.CASH)].balance = 10_000
portfolio_analytics = PortfolioAnalytics(portfolio20)

# %%
# stock 1
stock1 = Stock(product_id=101, description="Moon UK LLC", minimum_purchase_value=1, smallest_trading_unit=1, issue_currency='GBP')
product_collection.add_product(stock1)

# fund 2
fund1 = Stock(product_id=102, description="Sun City Fund", minimum_purchase_value=.001, smallest_trading_unit=.001, issue_currency='EUR')
product_collection.add_product(fund1)

# bond 1
bond1 = Bond(instrument_id=201, description="NL GOV 5% 2024", minimum_purchase_value=1000, smallest_trading_unit=1000, issue_currency='EUR', start_date=date(2024, 1, 1), maturity_date=date(2024, 12, 31), interest_rate=0.05, interest_payment_frequency=PaymentFrequency.YEAR)
product_collection.add_product(bond1)

# bond 2 -nog 30-360
bond2 = Bond(instrument_id=202, description="US GOV 3% 2022-2032", minimum_purchase_value=1000, smallest_trading_unit=1000, issue_currency='USD', start_date=date(2022, 11, 1), maturity_date=date(2032, 10, 31), interest_rate=0.03, interest_payment_frequency=PaymentFrequency.YEAR)
product_collection.add_product(bond2)

# bond 3 
bond3 = Bond(instrument_id=203, description="NL GOV 4% 2020-2025", minimum_purchase_value=1000, smallest_trading_unit=1000, issue_currency='USD', start_date=date(2020, 1, 1), maturity_date=date(2025, 12, 31), interest_rate=0.04, interest_payment_frequency=PaymentFrequency.END_DATE)
product_collection.add_product(bond3)

product_collection.list_products()
# Out:
# Product Collection:
# +-----------------+---------------------+--------+--------------------------+-------------------------+------------------+--------------+-----------------+-----------------+---------------------+
# |   Instrument ID | Description         | Type   |   Minimum Purchase Value |   Smallest Trading Unit | Issue Currency   | Start Date   | Maturity Date   | Interest Rate   | Payment Frequency   |
# +=================+=====================+========+==========================+=========================+==================+==============+=================+=================+=====================+
# |             101 | Moon UK LLC         | STOCK  |                    1     |                   1     | GBP              | N/A          | N/A             | N/A             | N/A                 |
# ...

# %%
# stock1 koersen
stock1.add_price(date(2023, 12, 31), 90)
stock1.add_price(date(2024, 1, 31), 100)
stock1.add_price(date(2024, 2, 29), 110)
stock1.add_price(date(2024, 3, 31), 120)
stock1.add_price(date(2024, 4, 30), 130)
stock1.add_price(date(2024, 5, 31), 140)
stock1.add_price(date(2024, 6, 30), 150)
stock1.add_price(date(2024, 7, 31), 160)
stock1.add_price(date(2024, 8, 31), 170)
stock1.add_price(date(2024, 9, 30), 180)
stock1.add_price(date(2024, 10, 31), 190)
stock1.add_price(date(2024, 11, 30), 200)
stock1.add_price(date(2024, 12, 31), 210)

# fund1 koersen
fund1.add_price(date(2023, 12, 31), 15.5)
fund1.add_price(date(2024, 1, 31), 15.8)
fund1.add_price(date(2024, 2, 29), 16.1)
fund1.add_price(date(2024, 3, 31), 16.4)
fund1.add_price(date(2024, 4, 30), 16.7)
fund1.add_price(date(2024, 5, 31), 17.0)
fund1.add_price(date(2024, 6, 30), 17.3)
fund1.add_price(date(2024, 7, 31), 17.6)
fund1.add_price(date(2024, 8, 31), 17.9)
fund1.add_price(date(2024, 9, 30), 18.2)
fund1.add_price(date(2024, 10, 31), 18.5)
fund1.add_price(date(2024, 11, 30), 18.8)
fund1.add_price(date(2024, 12, 31), 19.1)

# bond1 koersen
bond1.add_price(date(2023, 12, 31), 1.01)
bond1.add_price(date(2024, 1, 31), 1.02)
bond1.add_price(date(2024, 2, 29), 1.03)
bond1.add_price(date(2024, 3, 31), 1.04)
bond1.add_price(date(2024, 4, 30), 1.05)
bond1.add_price(date(2024, 5, 31), 1.06)
bond1.add_price(date(2024, 6, 30), 1.07)
bond1.add_price(date(2024, 7, 31), 1.08)
bond1.add_price(date(2024, 8, 31), 1.09)
bond1.add_price(date(2024, 9, 30), 1.10)
bond1.add_price(date(2024, 10, 31), 1.11)
bond1.add_price(date(2024, 11, 30), 1.12)
bond1.add_price(date(2024, 12, 31), 1.13)

# bond2 koersen
bond2.add_price(date(2023, 12, 31), 0.99)
bond2.add_price(date(2024, 1, 31), 0.985)
bond2.add_price(date(2024, 2, 29), 0.98)
bond2.add_price(date(2024, 3, 31), 0.975)
bond2.add_price(date(2024, 4, 30), 0.97)
bond2.add_price(date(2024, 5, 31), 0.965)
bond2.add_price(date(2024, 6, 30), 0.96)
bond2.add_price(date(2024, 7, 31), 0.955)
bond2.add_price(date(2024, 8, 31), 0.95)
bond2.add_price(date(2024, 9, 30), 0.945)
bond2.add_price(date(2024, 10, 31), 0.94)
bond2.add_price(date(2024, 11, 30), 0.935)
bond2.add_price(date(2024, 12, 31), 0.93)

# bond3 koersen
bond3.add_price(date(2023, 12, 31), 1.10)
bond3.add_price(date(2024, 1, 31), 1.11)
bond3.add_price(date(2024, 2, 29), 1.12)
bond3.add_price(date(2024, 3, 31), 1.13)
bond3.add_price(date(2024, 4, 30), 1.14)
bond3.add_price(date(2024, 5, 31), 1.15)
bond3.add_price(date(2024, 6, 30), 1.16)
bond3.add_price(date(2024, 7, 31), 1.15)
bond3.add_price(date(2024, 8, 31), 1.14)
bond3.add_price(date(2024, 9, 30), 1.13)
bond3.add_price(date(2024, 10, 31), 1.12)
bond3.add_price(date(2024, 11, 30), 1.11)
bond3.add_price(date(2024, 12, 31), 1.10)

# %%
currency_prices.add_price('USD', date(2024,1,1), 0.9250)
currency_prices.add_price('USD', date(2024,1,2), 0.9186)
currency_prices.add_price('USD', date(2024,1,3), 0.9265)
currency_prices.add_price('USD', date(2024,1,4), 0.9352)
currency_prices.add_price('USD', date(2024,1,5), 0.9177)
currency_prices.add_price('USD', date(2024,1,8), 0.9177)
currency_prices.add_price('USD', date(2024,1,9), 0.9358)
currency_prices.add_price('USD', date(2024,1,10), 0.9277)
currency_prices.add_price('USD', date(2024,1,11), 0.9153)
currency_prices.add_price('USD', date(2024,1,12), 0.9254)
currency_prices.add_price('USD', date(2024,1,15), 0.9251)
currency_prices.add_price('USD', date(2024,1,16), 0.9242)
currency_prices.add_price('USD', date(2024,1,17), 0.9312)
currency_prices.add_price('USD', date(2024,1,18), 0.9285)
currency_prices.add_price('USD', date(2024,1,19), 0.9159)
currency_prices.add_price('USD', date(2024,1,22), 0.9257)
currency_prices.add_price('USD', date(2024,1,23), 0.9215)
currency_prices.add_price('USD', date(2024,1,24), 0.9306)
currency_prices.add_price('USD', date(2024,1,25), 0.9157)
currency_prices.add_price('USD', date(2024,1,26), 0.9181)
currency_prices.add_price('USD', date(2024,1,29), 0.9267)
currency_prices.add_price('USD', date(2024,1,30), 0.9175)
currency_prices.add_price('USD', date(2024,1,31), 0.9245)
currency_prices.add_price('USD', date(2024,2,1), 0.9274)
currency_prices.add_price('USD', date(2024,2,2), 0.9261)
currency_prices.add_price('USD', date(2024,2,5), 0.9242)
currency_prices.add_price('USD', date(2024,2,6), 0.9265)
currency_prices.add_price('USD', date(2024,2,7), 0.9292)
currency_prices.add_price('USD', date(2024,2,8), 0.9240)
currency_prices.add_price('USD', date(2024,2,9), 0.9267)
currency_prices.add_price('USD', date(2024,2,12), 0.9249)
currency_prices.add_price('USD', date(2024,2,13), 0.9247)
currency_prices.add_price('USD', date(2024,2,14), 0.9316)
currency_prices.add_price('USD', date(2024,2,15), 0.9219)
currency_prices.add_price('USD', date(2024,2,16), 0.9203)
currency_prices.add_price('USD', date(2024,2,19), 0.9260)
currency_prices.add_price('USD', date(2024,2,20), 0.9261)
currency_prices.add_price('USD', date(2024,2,21), 0.9263)
currency_prices.add_price('USD', date(2024,2,22), 0.9264)
currency_prices.add_price('USD', date(2024,2,23), 0.9251)
currency_prices.add_price('USD', date(2024,2,26), 0.9227)
currency_prices.add_price('USD', date(2024,2,27), 0.9308)
currency_prices.add_price('USD', date(2024,2,28), 0.9267)
currency_prices.add_price('USD', date(2024,2,29), 0.9267)
currency_prices.add_price('USD', date(2024,3,1), 0.9302)
currency_prices.add_price('USD', date(2024,3,4), 0.9254)
currency_prices.add_price('USD', date(2024,3,5), 0.9226)
currency_prices.add_price('USD', date(2024,3,6), 0.9265)
currency_prices.add_price('USD', date(2024,3,7), 0.9216)
currency_prices.add_price('USD', date(2024,3,8), 0.9282)
currency_prices.add_price('USD', date(2024,3,11), 0.9267)
currency_prices.add_price('USD', date(2024,3,12), 0.9247)
currency_prices.add_price('USD', date(2024,3,13), 0.9277)
currency_prices.add_price('USD', date(2024,3,14), 0.9240)
currency_prices.add_price('USD', date(2024,3,15), 0.9264)
currency_prices.add_price('USD', date(2024,3,18), 0.9273)
currency_prices.add_price('USD', date(2024,3,19), 0.9253)
currency_prices.add_price('USD', date(2024,3,20), 0.9238)
currency_prices.add_price('USD', date(2024,3,21), 0.9246)
currency_prices.add_price('USD', date(2024,3,22), 0.9255)
currency_prices.add_price('USD', date(2024,3,25), 0.9258)
currency_prices.add_price('USD', date(2024,3,26), 0.9267)
currency_prices.add_price('USD', date(2024,3,27), 0.9233)
currency_prices.add_price('USD', date(2024,3,28), 0.9264)
currency_prices.add_price('USD', date(2024,3,29), 0.9267)
currency_prices.add_price('USD', date(2024,4,1), 0.9238)
currency_prices.add_price('USD', date(2024,4,2), 0.9253)
currency_prices.add_price('USD', date(2024,4,3), 0.9282)
currency_prices.add_price('USD', date(2024,4,4), 0.9238)
currency_prices.add_price('USD', date(2024,4,5), 0.9243)
currency_prices.add_price('USD', date(2024,4,8), 0.9263)
currency_prices.add_price('USD', date(2024,4,9), 0.9250)
currency_prices.add_price('USD', date(2024,4,10), 0.9264)
currency_prices.add_price('USD', date(2024,4,11), 0.9241)
currency_prices.add_price('USD', date(2024,4,12), 0.9260)
currency_prices.add_price('USD', date(2024,4,15), 0.9252)
currency_prices.add_price('USD', date(2024,4,16), 0.9256)
currency_prices.add_price('USD', date(2024,4,17), 0.9260)
currency_prices.add_price('USD', date(2024,4,18), 0.9277)
currency_prices.add_price('USD', date(2024,4,19), 0.9266)
currency_prices.add_price('USD', date(2024,4,22), 0.9252)
currency_prices.add_price('USD', date(2024,4,23), 0.9258)
currency_prices.add_price('USD', date(2024,4,24), 0.9254)
currency_prices.add_price('USD', date(2024,4,25), 0.9259)
currency_prices.add_price('USD', date(2024,4,26), 0.9262)
currency_prices.add_price('USD', date(2024,4,29), 0.9265)
currency_prices.add_price('USD', date(2024,4,30), 0.9260)
currency_prices.add_price('USD', date(2024,5,1), 0.9268)
currency_prices.add_price('USD', date(2024,5,2), 0.9271)
currency_prices.add_price('USD', date(2024,5,3), 0.9263)
currency_prices.add_price('USD', date(2024,5,6), 0.9258)
currency_prices.add_price('USD', date(2024,5,7), 0.9266)
currency_prices.add_price('USD', date(2024,5,8), 0.9259)
currency_prices.add_price('USD', date(2024,5,9), 0.9265)
currency_prices.add_price('USD', date(2024,5,10), 0.9267)
currency_prices.add_price('USD', date(2024,5,13), 0.9262)
currency_prices.add_price('USD', date(2024,5,14), 0.9254)
currency_prices.add_price('USD', date(2024,5,15), 0.9258)
currency_prices.add_price('USD', date(2024,5,16), 0.9265)
currency_prices.add_price('USD', date(2024,5,17), 0.9260)
currency_prices.add_price('USD', date(2024,5,20), 0.9257)
currency_prices.add_price('USD', date(2024,5,21), 0.9263)
currency_prices.add_price('USD', date(2024,5,22), 0.9262)
currency_prices.add_price('USD', date(2024,5,23), 0.9260)
currency_prices.add_price('USD', date(2024,5,24), 0.9265)
currency_prices.add_price('USD', date(2024,5,27), 0.9260)
currency_prices.add_price('USD', date(2024,5,28), 0.9257)
currency_prices.add_price('USD', date(2024,5,29), 0.9261)
currency_prices.add_price('USD', date(2024,5,30), 0.9267)
currency_prices.add_price('USD', date(2024,5,31), 0.9262)
currency_prices.add_price('USD', date(2024,6,3), 0.9260)
currency_prices.add_price('USD', date(2024,6,4), 0.9258)
currency_prices.add_price('USD', date(2024,6,5), 0.9263)
currency_prices.add_price('USD', date(2024,6,6), 0.9267)
currency_prices.add_price('USD', date(2024,6,7), 0.9260)
currency_prices.add_price('USD', date(2024,6,10), 0.9259)
currency_prices.add_price('USD', date(2024,6,11), 0.9260)
currency_prices.add_price('USD', date(2024,6,12), 0.9264)
currency_prices.add_price('USD', date(2024,6,13), 0.9260)
currency_prices.add_price('USD', date(2024,6,14), 0.9262)
currency_prices.add_price('USD', date(2024,6,17), 0.9265)
currency_prices.add_price('USD', date(2024,6,18), 0.9258)
currency_prices.add_price('USD', date(2024,6,19), 0.9263)
currency_prices.add_price('USD', date(2024,6,20), 0.9260)
currency_prices.add_price('USD', date(2024,6,21), 0.9265)
currency_prices.add_price('USD', date(2024,6,24), 0.9261)
currency_prices.add_price('USD', date(2024,6,25), 0.9263)
currency_prices.add_price('USD', date(2024,6,26), 0.9260)
currency_prices.add_price('USD', date(2024,6,27), 0.9264)
currency_prices.add_price('USD', date(2024,6,28), 0.9262)
currency_prices.add_price('USD', date(2024,6,30), 0.9265)

# %%
currency_prices.add_price('GBP', date(2024,1,1), 1.1345)
currency_prices.add_price('GBP', date(2024,1,2), 1.1507)
currency_prices.add_price('GBP', date(2024,1,3), 1.1394)
currency_prices.add_price('GBP', date(2024,1,4), 1.1547)
currency_prices.add_price('GBP', date(2024,1,5), 1.1408)
currency_prices.add_price('GBP', date(2024,1,8), 1.1655)
currency_prices.add_price('GBP', date(2024,1,9), 1.1422)
currency_prices.add_price('GBP', date(2024,1,10), 1.1468)
currency_prices.add_price('GBP', date(2024,1,11), 1.1581)
currency_prices.add_price('GBP', date(2024,1,12), 1.1377)
currency_prices.add_price('GBP', date(2024,1,15), 1.1559)
currency_prices.add_price('GBP', date(2024,1,16), 1.1497)
currency_prices.add_price('GBP', date(2024,1,17), 1.1512)
currency_prices.add_price('GBP', date(2024,1,18), 1.1445)
currency_prices.add_price('GBP', date(2024,1,19), 1.1521)
currency_prices.add_price('GBP', date(2024,1,22), 1.1453)
currency_prices.add_price('GBP', date(2024,1,23), 1.1437)
currency_prices.add_price('GBP', date(2024,1,24), 1.1561)
currency_prices.add_price('GBP', date(2024,1,25), 1.1355)
currency_prices.add_price('GBP', date(2024,1,26), 1.1523)
currency_prices.add_price('GBP', date(2024,1,29), 1.1549)
currency_prices.add_price('GBP', date(2024,1,30), 1.1480)
currency_prices.add_price('GBP', date(2024,1,31), 1.1534)
currency_prices.add_price('GBP', date(2024,2,1), 1.1469)
currency_prices.add_price('GBP', date(2024,2,2), 1.1540)
currency_prices.add_price('GBP', date(2024,2,5), 1.1535)
currency_prices.add_price('GBP', date(2024,2,6), 1.1547)
currency_prices.add_price('GBP', date(2024,2,7), 1.1502)
currency_prices.add_price('GBP', date(2024,2,8), 1.1533)
currency_prices.add_price('GBP', date(2024,2,9), 1.1509)
currency_prices.add_price('GBP', date(2024,2,12), 1.1514)
currency_prices.add_price('GBP', date(2024,2,13), 1.1545)
currency_prices.add_price('GBP', date(2024,2,14), 1.1513)
currency_prices.add_price('GBP', date(2024,2,15), 1.1476)
currency_prices.add_price('GBP', date(2024,2,16), 1.1517)
currency_prices.add_price('GBP', date(2024,2,19), 1.1490)
currency_prices.add_price('GBP', date(2024,2,20), 1.1526)
currency_prices.add_price('GBP', date(2024,2,21), 1.1538)
currency_prices.add_price('GBP', date(2024,2,22), 1.1554)
currency_prices.add_price('GBP', date(2024,2,23), 1.1517)
currency_prices.add_price('GBP', date(2024,2,26), 1.1540)
currency_prices.add_price('GBP', date(2024,2,27), 1.1513)
currency_prices.add_price('GBP', date(2024,2,28), 1.1544)
currency_prices.add_price('GBP', date(2024,2,29), 1.1522)
currency_prices.add_price('GBP', date(2024,3,1), 1.1541)
currency_prices.add_price('GBP', date(2024,3,4), 1.1550)
currency_prices.add_price('GBP', date(2024,3,5), 1.1514)
currency_prices.add_price('GBP', date(2024,3,6), 1.1558)
currency_prices.add_price('GBP', date(2024,3,7), 1.1506)
currency_prices.add_price('GBP', date(2024,3,8), 1.1542)
currency_prices.add_price('GBP', date(2024,3,11), 1.1547)
currency_prices.add_price('GBP', date(2024,3,12), 1.1544)
currency_prices.add_price('GBP', date(2024,3,13), 1.1539)
currency_prices.add_price('GBP', date(2024,3,14), 1.1552)
currency_prices.add_price('GBP', date(2024,3,15), 1.1536)
currency_prices.add_price('GBP', date(2024,3,18), 1.1557)
currency_prices.add_price('GBP', date(2024,3,19), 1.1546)
currency_prices.add_price('GBP', date(2024,3,20), 1.1514)
currency_prices.add_price('GBP', date(2024,3,21), 1.1531)
currency_prices.add_price('GBP', date(2024,3,22), 1.1554)
currency_prices.add_price('GBP', date(2024,3,25), 1.1527)
currency_prices.add_price('GBP', date(2024,3,26), 1.1532)
currency_prices.add_price('GBP', date(2024,3,27), 1.1519)
currency_prices.add_price('GBP', date(2024,3,28), 1.1523)
currency_prices.add_price('GBP', date(2024,3,29), 1.1535)
currency_prices.add_price('GBP', date(2024,4,1), 1.1548)
currency_prices.add_price('GBP', date(2024,4,2), 1.1539)
currency_prices.add_price('GBP', date(2024,4,3), 1.1536)
currency_prices.add_price('GBP', date(2024,4,4), 1.1525)
currency_prices.add_price('GBP', date(2024,4,5), 1.1550)
currency_prices.add_price('GBP', date(2024,4,8), 1.1537)
currency_prices.add_price('GBP', date(2024,4,9), 1.1531)
currency_prices.add_price('GBP', date(2024,4,10), 1.1551)
currency_prices.add_price('GBP', date(2024,4,11), 1.1533)
currency_prices.add_price('GBP', date(2024,4,12), 1.1549)
currency_prices.add_price('GBP', date(2024,4,15), 1.1556)
currency_prices.add_price('GBP', date(2024,4,16), 1.1534)
currency_prices.add_price('GBP', date(2024,4,17), 1.1551)
currency_prices.add_price('GBP', date(2024,4,18), 1.1543)
currency_prices.add_price('GBP', date(2024,4,19), 1.1528)
currency_prices.add_price('GBP', date(2024,4,22), 1.1546)
currency_prices.add_price('GBP', date(2024,4,23), 1.1537)
currency_prices.add_price('GBP', date(2024,4,24), 1.1550)
currency_prices.add_price('GBP', date(2024,4,25), 1.1539)
currency_prices.add_price('GBP', date(2024,4,26), 1.1544)
currency_prices.add_price('GBP', date(2024,4,29), 1.1543)
currency_prices.add_price('GBP', date(2024,4,30), 1.1537)
currency_prices.add_price('GBP', date(2024,5,1), 1.1542)
currency_prices.add_price('GBP', date(2024,5,2), 1.1535)
currency_prices.add_price('GBP', date(2024,5,3), 1.1546)
currency_prices.add_price('GBP', date(2024,5,6), 1.1533)
currency_prices.add_price('GBP', date(2024,5,7), 1.1538)
currency_prices.add_price('GBP', date(2024,5,8), 1.1534)
currency_prices.add_price('GBP', date(2024,5,9), 1.1540)
currency_prices.add_price('GBP', date(2024,5,10), 1.1541)
currency_prices.add_price('GBP', date(2024,5,13), 1.1537)
currency_prices.add_price('GBP', date(2024,5,14), 1.1530)
currency_prices.add_price('GBP', date(2024,5,15), 1.1544)
currency_prices.add_price('GBP', date(2024,5,16), 1.1538)
currency_prices.add_price('GBP', date(2024,5,17), 1.1531)
currency_prices.add_price('GBP', date(2024,5,20), 1.1535)
currency_prices.add_price('GBP', date(2024,5,21), 1.1541)
currency_prices.add_price('GBP', date(2024,5,22), 1.1543)
currency_prices.add_price('GBP', date(2024,5,23), 1.1539)
currency_prices.add_price('GBP', date(2024,5,24), 1.1540)
currency_prices.add_price('GBP', date(2024,5,27), 1.1537)
currency_prices.add_price('GBP', date(2024,5,28), 1.1542)
currency_prices.add_price('GBP', date(2024,5,29), 1.1540)
currency_prices.add_price('GBP', date(2024,5,30), 1.1539)
currency_prices.add_price('GBP', date(2024,5,31), 1.1538)
currency_prices.add_price('GBP', date(2024,6,3), 1.1539)
currency_prices.add_price('GBP', date(2024,6,4), 1.1542)
currency_prices.add_price('GBP', date(2024,6,5), 1.1541)
currency_prices.add_price('GBP', date(2024,6,6), 1.1535)
currency_prices.add_price('GBP', date(2024,6,7), 1.1539)
currency_prices.add_price('GBP', date(2024,6,10), 1.1543)
currency_prices.add_price('GBP', date(2024,6,11), 1.1537)
currency_prices.add_price('GBP', date(2024,6,12), 1.1535)
currency_prices.add_price('GBP', date(2024,6,13), 1.1538)
currency_prices.add_price('GBP', date(2024,6,14), 1.1540)
currency_prices.add_price('GBP', date(2024,6,17), 1.1539)
currency_prices.add_price('GBP', date(2024,6,18), 1.1536)
currency_prices.add_price('GBP', date(2024,6,19), 1.1539)
currency_prices.add_price('GBP', date(2024,6,20), 1.1541)
currency_prices.add_price('GBP', date(2024,6,21), 1.1543)
currency_prices.add_price('GBP', date(2024,6,24), 1.1542)
currency_prices.add_price('GBP', date(2024,6,25), 1.1538)
currency_prices.add_price('GBP', date(2024,6,26), 1.1541)
currency_prices.add_price('GBP', date(2024,6,27), 1.1539)
currency_prices.add_price('GBP', date(2024,6,28), 1.1538)
currency_prices.add_price('GBP', date(2024,6,30), 1.1542)

# %%
transaction_manager.create_and_execute_transaction(
    transaction_date=date(2024, 2, 15),
    portfolio_id=portfolio10.portfolio_id,
    template=TransactionTemplate.BUY,
    portfolio=portfolio10,
    product_collection=product_collection,
    currency_prices=currency_prices,
    product_id=101,
    amount=10,
    price=100,
    cost=12.34
)

transaction_manager.create_and_execute_transaction(
    transaction_date=date(2024, 3, 15),
    portfolio_id=portfolio10.portfolio_id,
    template=TransactionTemplate.BUY,
    portfolio=portfolio10,
    product_collection=product_collection,
    currency_prices=currency_prices,
    product_id=101,
    amount=5,
    price=100,
)

transaction_manager.create_and_execute_transaction(
    transaction_date=date(2024, 3, 15),
    portfolio_id=portfolio10.portfolio_id,
    template=TransactionTemplate.SELL,
    portfolio=portfolio10,
    product_collection=product_collection,
    currency_prices=currency_prices,
    product_id=101,
    amount=6,
    price=100,
)

transaction_manager.create_and_execute_transaction(
    transaction_date=date(2024, 4, 20),
    portfolio_id=portfolio10.portfolio_id,
    template=TransactionTemplate.SELL,
    portfolio=portfolio10,
    product_collection=product_collection,
    currency_prices=currency_prices,
    product_id=101,
    amount=4,
    price=100,
)

transaction_manager.create_and_execute_transaction(
    transaction_date=date(2024, 2, 20),
    portfolio_id=portfolio10.portfolio_id,
    template=TransactionTemplate.BUY,
    portfolio=portfolio10,
    product_collection=product_collection,
    currency_prices=currency_prices,
    product_id=102,
    amount=1.2345,
    price=20,
)

transaction_manager.create_and_execute_transaction(
    transaction_date=date(2024, 2, 25),
    portfolio_id=portfolio10.portfolio_id,
    template=TransactionTemplate.BUY,
    portfolio=portfolio10,
    product_collection=product_collection,
    currency_prices=currency_prices,
    product_id=102,
    amount=1.234,
    price=20,
)

transaction_manager.create_and_execute_transaction(
    transaction_date=date(2024, 1, 30),
    portfolio_id=portfolio10.portfolio_id,
    template=TransactionTemplate.BUY,
    portfolio=portfolio10,
    product_collection=product_collection,
    currency_prices=currency_prices,
    product_id=201,
    amount=5000,
    price=1.01,
)

transaction_manager.create_and_execute_transaction(
    transaction_date=date(2025, 1, 15),
    portfolio_id=portfolio10.portfolio_id,
    template=TransactionTemplate.BUY,
    portfolio=portfolio10,
    product_collection=product_collection,
    currency_prices=currency_prices,
    product_id=201,
    amount=1000,
    price=1.05,
)

transaction_manager.create_and_execute_transaction(
    transaction_date=date(2024, 1, 30),
    portfolio_id=portfolio10.portfolio_id,
    template=TransactionTemplate.BUY,
    portfolio=portfolio10,
    product_collection=product_collection,
    currency_prices=currency_prices,
    product_id=201,
    amount=5000,
    price=1.01,
)

transaction_manager.create_and_execute_transaction(
    transaction_date=date(2024, 2, 28),
    portfolio_id=portfolio10.portfolio_id,
    template=TransactionTemplate.BUY,
    portfolio=portfolio10,
    product_collection=product_collection,
    currency_prices=currency_prices,
    product_id=203,
    amount=1000,
    price=.98,
)

transaction_manager.create_and_execute_transaction(
    transaction_date=date(2024, 3, 31),
    portfolio_id=portfolio10.portfolio_id,
    template=TransactionTemplate.BUY,
    portfolio=portfolio10,
    product_collection=product_collection,
    currency_prices=currency_prices,
    product_id=202,
    amount=2000,
    price=.99,
)

transaction_manager.create_and_execute_transaction(
    transaction_date=date(2024, 3, 31),
    portfolio_id=portfolio20.portfolio_id,
    template=TransactionTemplate.BUY,
    portfolio=portfolio20,
    product_collection=product_collection,
    currency_prices=currency_prices,
    product_id=202,
    amount=4000,
    price=.98,
)

transaction_manager.create_and_execute_transaction(
    transaction_date=date(2024, 4, 30),
    portfolio_id=portfolio10.portfolio_id,
    template=TransactionTemplate.BUY,
    portfolio=portfolio10,
    product_collection=product_collection,
    currency_prices=currency_prices,
    product_id=202,
    amount=1000,
    price=.97,
)

transaction_manager.create_and_execute_transaction(
    transaction_date=date(2024, 5, 31),
    portfolio_id=portfolio20.portfolio_id,
    template=TransactionTemplate.SELL,
    portfolio=portfolio20,
    product_collection=product_collection,
    currency_prices=currency_prices,
    product_id=202,
    amount=2000,
    price=.99,
)

transaction_manager.create_and_execute_transaction(
    transaction_date=date(2024, 2, 28),
    portfolio_id=portfolio10.portfolio_id,
    template=TransactionTemplate.BUY,
    portfolio=portfolio10,
    product_collection=product_collection,
    currency_prices=currency_prices,
    product_id=203,
    amount=1000,
    price=1.1,
)
# Out:
# ERROR:root:Transaction validation (9) failed with messages: ['Insufficient balance for the total transaction amount in GBP. Account balance: 1000, Required: 1012.34']
# ERROR:root:Transaction validation (11) failed with messages: ['Insufficient holdings for product 101.']
# ERROR:root:Transaction validation (13) failed with messages: ['The transaction amount for product 102 is not a multiple of the smallest trading unit.']
# ERROR:root:Transaction validation (16) failed with messages: ['The transaction date for product 201 is outside the valid date range (2024-01-01 to 2024-12-31).']
# ERROR:root:Transaction validation (23) failed with messages: ['Insufficient balance for the total transaction amount in USD. Account balance: 735.3448087431693, Required: 1277.0109289617485']
# ['Insufficient balance for the total transaction amount in USD. Account balance: 735.3448087431693, Required: 1277.0109289617485']

# %%
portfolio10.list_accounts()
portfolio20.list_accounts()
portfolio10.list_holdings(time_travel, date(2024,6,30))
portfolio20.list_holdings(time_travel, date(2024,6,30))
portfolio10.transactions_table()
portfolio20.transactions_table()
portfolio10.list_accounts()
portfolio20.list_accounts()
portfolio10.returns_table(start_date=date(2024, 1, 1), end_date=date(2024, 12, 31))
portfolio20.returns_table(start_date=date(2024, 1, 1), end_date=date(2024, 12, 31))
# Out:
# Accounts in Portfolio 10:
# +--------------+------------+----------------+-------------------+
# |   Account ID | Currency   | Account Type   | Balance           |
# +==============+============+================+===================+
# |           10 | EUR        | CASH           | 4734.347172602738 |
# +--------------+------------+----------------+-------------------+
# |           10 | USD        | CASH           | 735.3448087431693 |
# +--------------+------------+----------------+-------------------+
# |           10 | GBP        | CASH           | 891.0             |
# +--------------+------------+----------------+-------------------+
# |           10 | EUR        | Securities     | N/A               |
# +--------------+------------+----------------+-------------------+
# Accounts in Portfolio 20:
# +--------------+------------+----------------+-------------------+
# |   Account ID | Currency   | Account Type   | Balance           |
# ...
